# %% [markdown]
# <a href="https://colab.research.google.com/github/ywchanna2001/Stock-price-prediction-with-LSTM/blob/main/Microsoftsock_forecasting_with_LSTMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061434
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063628
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064725
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.063079
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061982
# ...          ...         ...         ...         ...         ...         ...
# 9078  2022-03-18  295.369995  301.000000  292.730011  300.429993  300.429993
# 9079  2022-03-21  298.890015  300.140015  294.899994  299.160004  299.160004
# 9080  2022-03-22  299.799988  305.000000  298.769989  304.059998  304.059998
# 9081  2022-03-23  300.510010  303.230011  297.720001  299.489990  299.489990
# 9082  2022-03-24  299.140015  304.200012  298.320007  304.100006  304.100006
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9078    43317000
# 9079    28351200
# 9080    27599700
# 9081    25715400
# 9082    24446900
#
# [9083 rows x 7 columns]

# %%
df = df[['Date', 'Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9078  2022-03-18  300.429993
# 9079  2022-03-21  299.160004
# 9080  2022-03-22  304.059998
# 9081  2022-03-23  299.489990
# 9082  2022-03-24  304.100006
#
# [9083 rows x 2 columns]

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

detetime_object = str_to_datetime('1986-03-19')
detetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-5-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9078   2022-03-18
# 9079   2022-03-21
# 9080   2022-03-22
# 9081   2022-03-23
# 9082   2022-03-24
# Name: Date, Length: 9083, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2022-03-18  300.429993
# 2022-03-21  299.160004
# 2022-03-22  304.059998
# 2022-03-23  299.489990
# 2022-03-24  304.100006
#
# [9083 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '1986-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     1986-03-25    0.095486    0.092882    0.090278    0.092014
# 1     1986-03-26    0.092882    0.090278    0.092014    0.094618
# 2     1986-03-27    0.090278    0.092014    0.094618    0.096354
# 3     1986-03-31    0.092014    0.094618    0.096354    0.095486
# 4     1986-04-01    0.094618    0.096354    0.095486    0.094618
# ...          ...         ...         ...         ...         ...
# 9069  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 9070  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 9071  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 9072  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 9073  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [9074 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((9074,), (9074, 3, 1), (9074,))

# %%
q_80 = int(len(dates) * 0.8)
q_90 = int(len(dates) * 0.9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3,1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 298.3501 - mean_absolute_error: 11.2915 - val_loss: 526.6982 - val_mean_absolute_error: 15.5070
# Epoch 2/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3755 - mean_absolute_error: 0.3354 - val_loss: 405.0236 - val_mean_absolute_error: 12.7364
# Epoch 3/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3251 - mean_absolute_error: 0.3160 - val_loss: 359.7953 - val_mean_absolute_error: 11.8353
# Epoch 4/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2822 - mean_absolute_error: 0.3079 - val_loss: 337.1273 - val_mean_absolute_error: 11.1360
# Epoch 5/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3255 - mean_absolute_error: 0.3390 - val_loss: 328.0844 - val_mean_absolute_error: 10.9897
# Epoch 6/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3537 - mean_absolute_error: 0.3394 - val_loss: 312.3426 - val_mean_absolute_error: 10.5072
# Epoch 7/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2735 - mean_absolute_error: 0.3113 - val_loss: 308.6087 - val_mean_absolute_error: 10.4908
# Epoch 8/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3122 - mean_absolute_error: 0.3307 - val_loss: 303.7932 - val_mean_absolute_error: 10.3051
# Epoch 9/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3775 - mean_absolute_error: 0.3605 - val_loss: 296.0163 - val_mean_absolute_error: 10.0920
# Epoch 10/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3500 - mean_absolute_error: 0.3502 - val_loss: 295.4805 - val_mean_absolute_error: 10.2413
# Epoch 11/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3437 - mean_absolute_error: 0.3330 - val_loss: 294.2800 - val_mean_absolute_error: 10.0502
# Epoch 12/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2953 - mean_absolute_error: 0.3108 - val_loss: 292.8034 - val_mean_absolute_error: 10.0707
# Epoch 13/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2992 - mean_absolute_error: 0.3163 - val_loss: 289.9004 - val_mean_absolute_error: 9.8970
# Epoch 14/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3402 - mean_absolute_error: 0.3522 - val_loss: 286.9298 - val_mean_absolute_error: 10.0035
# Epoch 15/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3549 - mean_absolute_error: 0.3636 - val_loss: 293.1729 - val_mean_absolute_error: 10.3185
# Epoch 16/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3240 - mean_absolute_error: 0.3295 - val_loss: 284.9307 - val_mean_absolute_error: 9.8511
# Epoch 17/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3034 - mean_absolute_error: 0.3181 - val_loss: 273.8404 - val_mean_absolute_error: 9.6796
# Epoch 18/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3341 - mean_absolute_error: 0.3329 - val_loss: 272.6955 - val_mean_absolute_error: 9.4923
# Epoch 19/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3241 - mean_absolute_error: 0.3307 - val_loss: 271.4528 - val_mean_absolute_error: 9.4896
# Epoch 20/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2853 - mean_absolute_error: 0.3043 - val_loss: 262.5520 - val_mean_absolute_error: 9.3906
# Epoch 21/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3069 - mean_absolute_error: 0.3325 - val_loss: 273.3804 - val_mean_absolute_error: 9.6750
# Epoch 22/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3085 - mean_absolute_error: 0.3323 - val_loss: 278.8098 - val_mean_absolute_error: 9.8379
# Epoch 23/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.3501 - mean_absolute_error: 0.3572 - val_loss: 277.8415 - val_mean_absolute_error: 9.7556
# Epoch 24/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2629 - mean_absolute_error: 0.3012 - val_loss: 272.5392 - val_mean_absolute_error: 9.5264
# Epoch 25/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2826 - mean_absolute_error: 0.3194 - val_loss: 266.3032 - val_mean_absolute_error: 9.3901
# Epoch 26/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3204 - mean_absolute_error: 0.3270 - val_loss: 263.9227 - val_mean_absolute_error: 9.6129
# Epoch 27/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2871 - mean_absolute_error: 0.3104 - val_loss: 255.4286 - val_mean_absolute_error: 9.1142
# Epoch 28/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3252 - mean_absolute_error: 0.3336 - val_loss: 271.4537 - val_mean_absolute_error: 9.7043
# Epoch 29/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2927 - mean_absolute_error: 0.3076 - val_loss: 260.8707 - val_mean_absolute_error: 9.2826
# Epoch 30/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2902 - mean_absolute_error: 0.3179 - val_loss: 255.1650 - val_mean_absolute_error: 9.1443
# Epoch 31/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3000 - mean_absolute_error: 0.3186 - val_loss: 257.1128 - val_mean_absolute_error: 9.2321
# Epoch 32/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3759 - mean_absolute_error: 0.3741 - val_loss: 260.0979 - val_mean_absolute_error: 9.4010
# Epoch 33/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2901 - mean_absolute_error: 0.3179 - val_loss: 258.8392 - val_mean_absolute_error: 9.4551
# Epoch 34/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3048 - mean_absolute_error: 0.3242 - val_loss: 248.0736 - val_mean_absolute_error: 8.9401
# Epoch 35/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2668 - mean_absolute_error: 0.3099 - val_loss: 242.5461 - val_mean_absolute_error: 8.8356
# Epoch 36/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3529 - mean_absolute_error: 0.3616 - val_loss: 249.2908 - val_mean_absolute_error: 9.0317
# Epoch 37/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2681 - mean_absolute_error: 0.3029 - val_loss: 238.0967 - val_mean_absolute_error: 8.9668
# Epoch 38/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2770 - mean_absolute_error: 0.3165 - val_loss: 230.9648 - val_mean_absolute_error: 8.6166
# Epoch 39/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3012 - mean_absolute_error: 0.3183 - val_loss: 237.5688 - val_mean_absolute_error: 8.9637
# Epoch 40/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2964 - mean_absolute_error: 0.3231 - val_loss: 249.2453 - val_mean_absolute_error: 9.3222
# Epoch 41/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3432 - mean_absolute_error: 0.3421 - val_loss: 228.3379 - val_mean_absolute_error: 8.5463
# Epoch 42/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2578 - mean_absolute_error: 0.2975 - val_loss: 221.3912 - val_mean_absolute_error: 8.7859
# Epoch 43/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3346 - mean_absolute_error: 0.3519 - val_loss: 252.4236 - val_mean_absolute_error: 9.4484
# Epoch 44/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2895 - mean_absolute_error: 0.3222 - val_loss: 234.9211 - val_mean_absolute_error: 8.6936
# Epoch 45/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3447 - mean_absolute_error: 0.3488 - val_loss: 252.9850 - val_mean_absolute_error: 9.2820
# Epoch 46/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2729 - mean_absolute_error: 0.3121 - val_loss: 241.3522 - val_mean_absolute_error: 8.9551
# Epoch 47/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3351 - mean_absolute_error: 0.3510 - val_loss: 242.2767 - val_mean_absolute_error: 8.9118
# Epoch 48/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2677 - mean_absolute_error: 0.3008 - val_loss: 242.2896 - val_mean_absolute_error: 8.9431
# Epoch 49/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3144 - mean_absolute_error: 0.3283 - val_loss: 230.8485 - val_mean_absolute_error: 8.8839
# Epoch 50/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3095 - mean_absolute_error: 0.3271 - val_loss: 238.4816 - val_mean_absolute_error: 8.9914
# Epoch 51/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3219 - mean_absolute_error: 0.3318 - val_loss: 237.1233 - val_mean_absolute_error: 8.8440
# Epoch 52/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2822 - mean_absolute_error: 0.3162 - val_loss: 240.9191 - val_mean_absolute_error: 8.9379
# Epoch 53/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3436 - mean_absolute_error: 0.3330 - val_loss: 228.2770 - val_mean_absolute_error: 8.5391
# Epoch 54/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3034 - mean_absolute_error: 0.3259 - val_loss: 255.6963 - val_mean_absolute_error: 9.5525
# Epoch 55/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2922 - mean_absolute_error: 0.3104 - val_loss: 247.9769 - val_mean_absolute_error: 9.2133
# Epoch 56/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2886 - mean_absolute_error: 0.3182 - val_loss: 233.9179 - val_mean_absolute_error: 8.6853
# Epoch 57/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3231 - mean_absolute_error: 0.3259 - val_loss: 231.0666 - val_mean_absolute_error: 8.6076
# Epoch 58/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3000 - mean_absolute_error: 0.3098 - val_loss: 249.2902 - val_mean_absolute_error: 9.2222
# Epoch 59/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3038 - mean_absolute_error: 0.3230 - val_loss: 243.4082 - val_mean_absolute_error: 9.0574
# Epoch 60/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3316 - mean_absolute_error: 0.3290 - val_loss: 234.2230 - val_mean_absolute_error: 8.7872
# Epoch 61/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2910 - mean_absolute_error: 0.3244 - val_loss: 229.7702 - val_mean_absolute_error: 8.7052
# Epoch 62/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3267 - mean_absolute_error: 0.3323 - val_loss: 257.5285 - val_mean_absolute_error: 9.5027
# Epoch 63/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3013 - mean_absolute_error: 0.3270 - val_loss: 234.5763 - val_mean_absolute_error: 8.7422
# Epoch 64/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2618 - mean_absolute_error: 0.3026 - val_loss: 224.4964 - val_mean_absolute_error: 8.4797
# Epoch 65/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2909 - mean_absolute_error: 0.3115 - val_loss: 238.1344 - val_mean_absolute_error: 8.8175
# Epoch 66/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2711 - mean_absolute_error: 0.2990 - val_loss: 237.3992 - val_mean_absolute_error: 8.9684
# Epoch 67/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3253 - mean_absolute_error: 0.3327 - val_loss: 234.2053 - val_mean_absolute_error: 8.7295
# Epoch 68/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2917 - mean_absolute_error: 0.3151 - val_loss: 240.5353 - val_mean_absolute_error: 8.9981
# Epoch 69/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2899 - mean_absolute_error: 0.3198 - val_loss: 227.5831 - val_mean_absolute_error: 8.5716
# Epoch 70/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2608 - mean_absolute_error: 0.2948 - val_loss: 230.3559 - val_mean_absolute_error: 8.8350
# Epoch 71/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3172 - mean_absolute_error: 0.3360 - val_loss: 241.3375 - val_mean_absolute_error: 8.9337
# Epoch 72/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3019 - mean_absolute_error: 0.3204 - val_loss: 230.6429 - val_mean_absolute_error: 8.5977
# Epoch 73/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2736 - mean_absolute_error: 0.3085 - val_loss: 228.0614 - val_mean_absolute_error: 8.6557
# Epoch 74/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2817 - mean_absolute_error: 0.3036 - val_loss: 233.3054 - val_mean_absolute_error: 8.7756
# Epoch 75/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2929 - mean_absolute_error: 0.3104 - val_loss: 240.4271 - val_mean_absolute_error: 9.1040
# Epoch 76/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3291 - mean_absolute_error: 0.3373 - val_loss: 223.5530 - val_mean_absolute_error: 8.6624
# Epoch 77/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2925 - mean_absolute_error: 0.3136 - val_loss: 222.0267 - val_mean_absolute_error: 8.5064
# Epoch 78/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2796 - mean_absolute_error: 0.3068 - val_loss: 219.1202 - val_mean_absolute_error: 8.3961
# Epoch 79/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2818 - mean_absolute_error: 0.3146 - val_loss: 212.6953 - val_mean_absolute_error: 8.1984
# Epoch 80/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2945 - mean_absolute_error: 0.2926 - val_loss: 228.9490 - val_mean_absolute_error: 8.9508
# Epoch 81/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2733 - mean_absolute_error: 0.3041 - val_loss: 213.1820 - val_mean_absolute_error: 8.3473
# Epoch 82/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3137 - mean_absolute_error: 0.3302 - val_loss: 219.8882 - val_mean_absolute_error: 8.4602
# Epoch 83/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2967 - mean_absolute_error: 0.3229 - val_loss: 218.6240 - val_mean_absolute_error: 8.3824
# Epoch 84/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3250 - mean_absolute_error: 0.3321 - val_loss: 212.0774 - val_mean_absolute_error: 8.1926
# Epoch 85/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2735 - mean_absolute_error: 0.3035 - val_loss: 218.4364 - val_mean_absolute_error: 8.5448
# Epoch 86/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3156 - mean_absolute_error: 0.3359 - val_loss: 236.2999 - val_mean_absolute_error: 8.9667
# Epoch 87/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2751 - mean_absolute_error: 0.3011 - val_loss: 227.5200 - val_mean_absolute_error: 8.7776
# Epoch 88/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2975 - mean_absolute_error: 0.3158 - val_loss: 229.3969 - val_mean_absolute_error: 8.6685
# Epoch 89/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2709 - mean_absolute_error: 0.3032 - val_loss: 210.8802 - val_mean_absolute_error: 8.2636
# Epoch 90/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2924 - mean_absolute_error: 0.3165 - val_loss: 231.1700 - val_mean_absolute_error: 8.7430
# Epoch 91/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2870 - mean_absolute_error: 0.3041 - val_loss: 220.8224 - val_mean_absolute_error: 8.3739
# Epoch 92/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2818 - mean_absolute_error: 0.3136 - val_loss: 234.5647 - val_mean_absolute_error: 8.9391
# Epoch 93/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3069 - mean_absolute_error: 0.3170 - val_loss: 227.1224 - val_mean_absolute_error: 8.6166
# Epoch 94/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2915 - mean_absolute_error: 0.3183 - val_loss: 235.4003 - val_mean_absolute_error: 9.1101
# Epoch 95/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2744 - mean_absolute_error: 0.3044 - val_loss: 237.0209 - val_mean_absolute_error: 9.3777
# Epoch 96/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3381 - mean_absolute_error: 0.3416 - val_loss: 202.8887 - val_mean_absolute_error: 7.9969
# Epoch 97/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2918 - mean_absolute_error: 0.3184 - val_loss: 201.4577 - val_mean_absolute_error: 7.9503
# Epoch 98/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3019 - mean_absolute_error: 0.3136 - val_loss: 216.0231 - val_mean_absolute_error: 8.3748
# Epoch 99/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2811 - mean_absolute_error: 0.3054 - val_loss: 220.9348 - val_mean_absolute_error: 8.5858
# Epoch 100/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3006 - mean_absolute_error: 0.3194 - val_loss: 224.2574 - val_mean_absolute_error: 8.5590

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
test_predictions = model.predict(X_test)

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)

plt.legend(['Training Predictions', 'Training Observations', 'Validation Predictions', 'Validation Observations', 'Test Predictions', 'Test Observations'])
