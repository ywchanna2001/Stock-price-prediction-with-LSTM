# %% [markdown]
# <a href="https://colab.research.google.com/github/ywchanna2001/Stock-price-prediction-with-LSTM/blob/main/Microsoftsock_forecasting_with_LSTMs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('MSFT.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1986-03-13    0.088542    0.101563    0.088542    0.097222    0.061434
# 1     1986-03-14    0.097222    0.102431    0.097222    0.100694    0.063628
# 2     1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064725
# 3     1986-03-18    0.102431    0.103299    0.098958    0.099826    0.063079
# 4     1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061982
# ...          ...         ...         ...         ...         ...         ...
# 9078  2022-03-18  295.369995  301.000000  292.730011  300.429993  300.429993
# 9079  2022-03-21  298.890015  300.140015  294.899994  299.160004  299.160004
# 9080  2022-03-22  299.799988  305.000000  298.769989  304.059998  304.059998
# 9081  2022-03-23  300.510010  303.230011  297.720001  299.489990  299.489990
# 9082  2022-03-24  299.140015  304.200012  298.320007  304.100006  304.100006
#
#           Volume
# 0     1031788800
# 1      308160000
# 2      133171200
# 3       67766400
# 4       47894400
# ...          ...
# 9078    43317000
# 9079    28351200
# 9080    27599700
# 9081    25715400
# 9082    24446900
#
# [9083 rows x 7 columns]

# %%
df = df[['Date', 'Close']]
df
# Out:
#             Date       Close
# 0     1986-03-13    0.097222
# 1     1986-03-14    0.100694
# 2     1986-03-17    0.102431
# 3     1986-03-18    0.099826
# 4     1986-03-19    0.098090
# ...          ...         ...
# 9078  2022-03-18  300.429993
# 9079  2022-03-21  299.160004
# 9080  2022-03-22  304.059998
# 9081  2022-03-23  299.489990
# 9082  2022-03-24  304.100006
#
# [9083 rows x 2 columns]

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

detetime_object = str_to_datetime('1986-03-19')
detetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-4-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      1986-03-13
# 1      1986-03-14
# 2      1986-03-17
# 3      1986-03-18
# 4      1986-03-19
#           ...
# 9078   2022-03-18
# 9079   2022-03-21
# 9080   2022-03-22
# 9081   2022-03-23
# 9082   2022-03-24
# Name: Date, Length: 9083, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2022-03-18  300.429993
# 2022-03-21  299.160004
# 2022-03-22  304.059998
# 2022-03-23  299.489990
# 2022-03-24  304.100006
#
# [9083 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '1986-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#      Target Date    Target-3    Target-2    Target-1      Target
# 0     1986-03-25    0.095486    0.092882    0.090278    0.092014
# 1     1986-03-26    0.092882    0.090278    0.092014    0.094618
# 2     1986-03-27    0.090278    0.092014    0.094618    0.096354
# 3     1986-03-31    0.092014    0.094618    0.096354    0.095486
# 4     1986-04-01    0.094618    0.096354    0.095486    0.094618
# ...          ...         ...         ...         ...         ...
# 9069  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 9070  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 9071  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 9072  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 9073  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [9074 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((9074,), (9074, 3, 1), (9074,))

# %%
q_80 = int(len(dates) * 0.8)
q_90 = int(len(dates) * 0.9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3,1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 283.6397 - mean_absolute_error: 10.9327 - val_loss: 544.0488 - val_mean_absolute_error: 15.9585
# Epoch 2/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4559 - mean_absolute_error: 0.3615 - val_loss: 412.6266 - val_mean_absolute_error: 12.9633
# Epoch 3/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3105 - mean_absolute_error: 0.3185 - val_loss: 362.5183 - val_mean_absolute_error: 11.7909
# Epoch 4/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3536 - mean_absolute_error: 0.3423 - val_loss: 336.7431 - val_mean_absolute_error: 11.5375
# Epoch 5/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3283 - mean_absolute_error: 0.3252 - val_loss: 322.5434 - val_mean_absolute_error: 10.8398
# Epoch 6/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3362 - mean_absolute_error: 0.3382 - val_loss: 315.4501 - val_mean_absolute_error: 10.6759
# Epoch 7/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3104 - mean_absolute_error: 0.3265 - val_loss: 315.5304 - val_mean_absolute_error: 11.3052
# Epoch 8/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3534 - mean_absolute_error: 0.3487 - val_loss: 301.5436 - val_mean_absolute_error: 10.3145
# Epoch 9/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2795 - mean_absolute_error: 0.3062 - val_loss: 296.7132 - val_mean_absolute_error: 10.2691
# Epoch 10/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2890 - mean_absolute_error: 0.3074 - val_loss: 288.7423 - val_mean_absolute_error: 9.9895
# Epoch 11/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3292 - mean_absolute_error: 0.3458 - val_loss: 290.1108 - val_mean_absolute_error: 9.9914
# Epoch 12/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3001 - mean_absolute_error: 0.3200 - val_loss: 285.9751 - val_mean_absolute_error: 9.8800
# Epoch 13/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3052 - mean_absolute_error: 0.3272 - val_loss: 288.0070 - val_mean_absolute_error: 9.9756
# Epoch 14/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3446 - mean_absolute_error: 0.3610 - val_loss: 295.9572 - val_mean_absolute_error: 10.4094
# Epoch 15/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2617 - mean_absolute_error: 0.2987 - val_loss: 275.2828 - val_mean_absolute_error: 9.7316
# Epoch 16/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2834 - mean_absolute_error: 0.3108 - val_loss: 272.5499 - val_mean_absolute_error: 9.6944
# Epoch 17/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3065 - mean_absolute_error: 0.3286 - val_loss: 271.8809 - val_mean_absolute_error: 9.7626
# Epoch 18/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2673 - mean_absolute_error: 0.3153 - val_loss: 279.3623 - val_mean_absolute_error: 9.9608
# Epoch 19/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3239 - mean_absolute_error: 0.3362 - val_loss: 271.4887 - val_mean_absolute_error: 9.6842
# Epoch 20/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4128 - mean_absolute_error: 0.3790 - val_loss: 266.7355 - val_mean_absolute_error: 9.8870
# Epoch 21/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2835 - mean_absolute_error: 0.3070 - val_loss: 265.0011 - val_mean_absolute_error: 9.7524
# Epoch 22/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3252 - mean_absolute_error: 0.3343 - val_loss: 250.8739 - val_mean_absolute_error: 9.0900
# Epoch 23/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2845 - mean_absolute_error: 0.3144 - val_loss: 245.0016 - val_mean_absolute_error: 8.9381
# Epoch 24/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3064 - mean_absolute_error: 0.3171 - val_loss: 250.6800 - val_mean_absolute_error: 9.1049
# Epoch 25/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2683 - mean_absolute_error: 0.2996 - val_loss: 239.1473 - val_mean_absolute_error: 8.9438
# Epoch 26/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3198 - mean_absolute_error: 0.3384 - val_loss: 251.7130 - val_mean_absolute_error: 9.2620
# Epoch 27/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3018 - mean_absolute_error: 0.3243 - val_loss: 257.8516 - val_mean_absolute_error: 9.4225
# Epoch 28/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2945 - mean_absolute_error: 0.3221 - val_loss: 285.3492 - val_mean_absolute_error: 10.7212
# Epoch 29/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3668 - mean_absolute_error: 0.3688 - val_loss: 261.7833 - val_mean_absolute_error: 9.5865
# Epoch 30/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3065 - mean_absolute_error: 0.3283 - val_loss: 264.9252 - val_mean_absolute_error: 9.7862
# Epoch 31/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3015 - mean_absolute_error: 0.3189 - val_loss: 244.3021 - val_mean_absolute_error: 8.9853
# Epoch 32/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2852 - mean_absolute_error: 0.3136 - val_loss: 238.9539 - val_mean_absolute_error: 8.8521
# Epoch 33/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2945 - mean_absolute_error: 0.3188 - val_loss: 247.1127 - val_mean_absolute_error: 9.1893
# Epoch 34/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3138 - mean_absolute_error: 0.3227 - val_loss: 242.6594 - val_mean_absolute_error: 9.0329
# Epoch 35/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3090 - mean_absolute_error: 0.3322 - val_loss: 239.0474 - val_mean_absolute_error: 8.8594
# Epoch 36/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3328 - mean_absolute_error: 0.3524 - val_loss: 241.4529 - val_mean_absolute_error: 9.0192
# Epoch 37/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3149 - mean_absolute_error: 0.3327 - val_loss: 238.6413 - val_mean_absolute_error: 8.9223
# Epoch 38/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2571 - mean_absolute_error: 0.3045 - val_loss: 254.9490 - val_mean_absolute_error: 9.5935
# Epoch 39/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2958 - mean_absolute_error: 0.3110 - val_loss: 253.3847 - val_mean_absolute_error: 9.4261
# Epoch 40/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3051 - mean_absolute_error: 0.3287 - val_loss: 232.6007 - val_mean_absolute_error: 8.6911
# Epoch 41/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2931 - mean_absolute_error: 0.3172 - val_loss: 238.3213 - val_mean_absolute_error: 8.9419
# Epoch 42/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2933 - mean_absolute_error: 0.3219 - val_loss: 231.9421 - val_mean_absolute_error: 8.7794
# Epoch 43/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3012 - mean_absolute_error: 0.3202 - val_loss: 231.9529 - val_mean_absolute_error: 8.8037
# Epoch 44/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2596 - mean_absolute_error: 0.2951 - val_loss: 236.9534 - val_mean_absolute_error: 8.9278
# Epoch 45/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2866 - mean_absolute_error: 0.3194 - val_loss: 226.2287 - val_mean_absolute_error: 8.6525
# Epoch 46/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3013 - mean_absolute_error: 0.3327 - val_loss: 225.7114 - val_mean_absolute_error: 8.6525
# Epoch 47/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3098 - mean_absolute_error: 0.3299 - val_loss: 240.7194 - val_mean_absolute_error: 9.1084
# Epoch 48/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2727 - mean_absolute_error: 0.3045 - val_loss: 228.2176 - val_mean_absolute_error: 8.6494
# Epoch 49/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2707 - mean_absolute_error: 0.3081 - val_loss: 247.0425 - val_mean_absolute_error: 9.6206
# Epoch 50/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3139 - mean_absolute_error: 0.3157 - val_loss: 216.3909 - val_mean_absolute_error: 8.3314
# Epoch 51/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3013 - mean_absolute_error: 0.3099 - val_loss: 224.8862 - val_mean_absolute_error: 8.5871
# Epoch 52/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2911 - mean_absolute_error: 0.3123 - val_loss: 227.4095 - val_mean_absolute_error: 8.6816
# Epoch 53/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2798 - mean_absolute_error: 0.3025 - val_loss: 221.6727 - val_mean_absolute_error: 8.4444
# Epoch 54/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2795 - mean_absolute_error: 0.3079 - val_loss: 212.3016 - val_mean_absolute_error: 8.2349
# Epoch 55/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2797 - mean_absolute_error: 0.3071 - val_loss: 215.6882 - val_mean_absolute_error: 8.3811
# Epoch 56/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2729 - mean_absolute_error: 0.3102 - val_loss: 225.5644 - val_mean_absolute_error: 8.7970
# Epoch 57/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3089 - mean_absolute_error: 0.3275 - val_loss: 218.1565 - val_mean_absolute_error: 8.4291
# Epoch 58/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2887 - mean_absolute_error: 0.3231 - val_loss: 221.6113 - val_mean_absolute_error: 8.6061
# Epoch 59/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3220 - mean_absolute_error: 0.3329 - val_loss: 216.0336 - val_mean_absolute_error: 8.4017
# Epoch 60/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2832 - mean_absolute_error: 0.3120 - val_loss: 231.1791 - val_mean_absolute_error: 8.7899
# Epoch 61/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2869 - mean_absolute_error: 0.3063 - val_loss: 231.8893 - val_mean_absolute_error: 8.8051
# Epoch 62/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3289 - mean_absolute_error: 0.3319 - val_loss: 220.1493 - val_mean_absolute_error: 8.4863
# Epoch 63/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3733 - mean_absolute_error: 0.3426 - val_loss: 254.0702 - val_mean_absolute_error: 9.6760
# Epoch 64/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3427 - mean_absolute_error: 0.3418 - val_loss: 232.6525 - val_mean_absolute_error: 8.8517
# Epoch 65/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2896 - mean_absolute_error: 0.3198 - val_loss: 214.6125 - val_mean_absolute_error: 8.3649
# Epoch 66/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3183 - mean_absolute_error: 0.3388 - val_loss: 225.9617 - val_mean_absolute_error: 8.8316
# Epoch 67/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2920 - mean_absolute_error: 0.3132 - val_loss: 234.0578 - val_mean_absolute_error: 8.8714
# Epoch 68/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.2881 - mean_absolute_error: 0.3053 - val_loss: 211.0594 - val_mean_absolute_error: 8.2431
# Epoch 69/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2819 - mean_absolute_error: 0.3085 - val_loss: 224.8103 - val_mean_absolute_error: 9.0667
# Epoch 70/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2956 - mean_absolute_error: 0.3230 - val_loss: 216.2566 - val_mean_absolute_error: 8.3873
# Epoch 71/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2551 - mean_absolute_error: 0.2951 - val_loss: 211.6371 - val_mean_absolute_error: 8.2473
# Epoch 72/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2810 - mean_absolute_error: 0.3142 - val_loss: 207.9667 - val_mean_absolute_error: 8.1611
# Epoch 73/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2947 - mean_absolute_error: 0.3108 - val_loss: 221.6126 - val_mean_absolute_error: 8.5277
# Epoch 74/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2753 - mean_absolute_error: 0.3026 - val_loss: 207.9948 - val_mean_absolute_error: 8.3246
# Epoch 75/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2837 - mean_absolute_error: 0.3180 - val_loss: 209.6936 - val_mean_absolute_error: 8.2030
# Epoch 76/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2741 - mean_absolute_error: 0.3023 - val_loss: 220.9375 - val_mean_absolute_error: 8.8408
# Epoch 77/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2575 - mean_absolute_error: 0.3015 - val_loss: 215.2708 - val_mean_absolute_error: 8.5058
# Epoch 78/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2753 - mean_absolute_error: 0.3032 - val_loss: 209.6609 - val_mean_absolute_error: 8.3708
# Epoch 79/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2800 - mean_absolute_error: 0.3081 - val_loss: 240.8597 - val_mean_absolute_error: 9.1764
# Epoch 80/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2896 - mean_absolute_error: 0.3146 - val_loss: 208.6530 - val_mean_absolute_error: 8.2947
# Epoch 81/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2833 - mean_absolute_error: 0.3187 - val_loss: 216.0659 - val_mean_absolute_error: 8.5535
# Epoch 82/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2644 - mean_absolute_error: 0.3036 - val_loss: 211.6410 - val_mean_absolute_error: 8.4343
# Epoch 83/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2844 - mean_absolute_error: 0.3138 - val_loss: 213.8507 - val_mean_absolute_error: 8.4554
# Epoch 84/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2741 - mean_absolute_error: 0.3038 - val_loss: 226.1378 - val_mean_absolute_error: 8.7359
# Epoch 85/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.2725 - mean_absolute_error: 0.3066 - val_loss: 212.2057 - val_mean_absolute_error: 8.3030
# Epoch 86/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2925 - mean_absolute_error: 0.3067 - val_loss: 205.3625 - val_mean_absolute_error: 8.2433
# Epoch 87/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2702 - mean_absolute_error: 0.2978 - val_loss: 228.0603 - val_mean_absolute_error: 8.7665
# Epoch 88/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2638 - mean_absolute_error: 0.2980 - val_loss: 212.2971 - val_mean_absolute_error: 8.3249
# Epoch 89/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2846 - mean_absolute_error: 0.3163 - val_loss: 192.1019 - val_mean_absolute_error: 8.0889
# Epoch 90/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3782 - mean_absolute_error: 0.3682 - val_loss: 213.5297 - val_mean_absolute_error: 8.4303
# Epoch 91/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2870 - mean_absolute_error: 0.3079 - val_loss: 216.6436 - val_mean_absolute_error: 8.7081
# Epoch 92/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3203 - mean_absolute_error: 0.3313 - val_loss: 209.0046 - val_mean_absolute_error: 8.2285
# Epoch 93/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2541 - mean_absolute_error: 0.2977 - val_loss: 217.7903 - val_mean_absolute_error: 8.9421
# Epoch 94/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3118 - mean_absolute_error: 0.3341 - val_loss: 207.2845 - val_mean_absolute_error: 8.1717
# Epoch 95/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2880 - mean_absolute_error: 0.3062 - val_loss: 194.0076 - val_mean_absolute_error: 7.8543
# Epoch 96/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2903 - mean_absolute_error: 0.3214 - val_loss: 196.1083 - val_mean_absolute_error: 7.9192
# Epoch 97/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3077 - mean_absolute_error: 0.3211 - val_loss: 211.4317 - val_mean_absolute_error: 8.3556
# Epoch 98/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2674 - mean_absolute_error: 0.3022 - val_loss: 225.7238 - val_mean_absolute_error: 8.7490
# Epoch 99/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2604 - mean_absolute_error: 0.2983 - val_loss: 221.9851 - val_mean_absolute_error: 8.9431
# Epoch 100/100
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2898 - mean_absolute_error: 0.3168 - val_loss: 191.8983 - val_mean_absolute_error: 7.8383

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 227/227 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
test_predictions = model.predict(X_test)

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)

plt.legend(['Training Predictions', 'Training Observations', 'Validation Predictions', 'Validation Observations', 'Test Predictions', 'Test Observations'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  235.990005  237.580002  235.460007  232.339996
# 1    2021-03-26  237.580002  235.460007  232.339996  236.479996
# 2    2021-03-29  235.460007  232.339996  236.479996  235.240005
# 3    2021-03-30  232.339996  236.479996  235.240005  231.850006
# 4    2021-03-31  236.479996  235.240005  231.850006  235.770004
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  276.440002  287.149994  294.390015  295.220001
# 248  2022-03-18  287.149994  294.390015  295.220001  300.429993
# 249  2022-03-21  294.390015  295.220001  300.429993  299.160004
# 250  2022-03-22  295.220001  300.429993  299.160004  304.059998
# 251  2022-03-23  300.429993  299.160004  304.059998  299.489990
#
# [252 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * 0.8)
q_90 = int(len(dates) * 0.9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]
dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
 from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3,1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 84241.5391 - mean_absolute_error: 288.5402 - val_loss: 92487.5391 - val_mean_absolute_error: 304.0306
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 85514.8281 - mean_absolute_error: 290.7038 - val_loss: 92283.0781 - val_mean_absolute_error: 303.6941
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 84374.2031 - mean_absolute_error: 288.6989 - val_loss: 92071.6797 - val_mean_absolute_error: 303.3459
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 84864.1484 - mean_absolute_error: 289.6332 - val_loss: 91724.0000 - val_mean_absolute_error: 302.7723
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 82430.4219 - mean_absolute_error: 285.4200 - val_loss: 91298.7109 - val_mean_absolute_error: 302.0691
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 82821.2031 - mean_absolute_error: 286.0724 - val_loss: 90838.6562 - val_mean_absolute_error: 301.3066
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 82084.8984 - mean_absolute_error: 284.7595 - val_loss: 90255.0234 - val_mean_absolute_error: 300.3365
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 81641.5391 - mean_absolute_error: 283.9554 - val_loss: 89257.7422 - val_mean_absolute_error: 298.6716
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 82342.2031 - mean_absolute_error: 285.2899 - val_loss: 87999.7031 - val_mean_absolute_error: 296.5579
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 80674.1094 - mean_absolute_error: 282.2054 - val_loss: 86002.1719 - val_mean_absolute_error: 293.1708
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 77287.0234 - mean_absolute_error: 276.2878 - val_loss: 83880.2031 - val_mean_absolute_error: 289.5294
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 76940.0000 - mean_absolute_error: 275.5777 - val_loss: 81781.8516 - val_mean_absolute_error: 285.8826
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 73365.6172 - mean_absolute_error: 269.1486 - val_loss: 79346.7031 - val_mean_absolute_error: 281.5914
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 71354.2812 - mean_absolute_error: 265.2365 - val_loss: 76370.4531 - val_mean_absolute_error: 276.2561
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 68883.6328 - mean_absolute_error: 260.4922 - val_loss: 72991.6328 - val_mean_absolute_error: 270.0715
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 65208.7812 - mean_absolute_error: 253.3544 - val_loss: 68508.6953 - val_mean_absolute_error: 261.6401
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 60894.3281 - mean_absolute_error: 244.6762 - val_loss: 63141.4062 - val_mean_absolute_error: 251.1738
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 55143.8789 - mean_absolute_error: 232.8216 - val_loss: 57545.0508 - val_mean_absolute_error: 239.7749
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 50506.1250 - mean_absolute_error: 222.4830 - val_loss: 51240.8555 - val_mean_absolute_error: 226.2472
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 44337.8594 - mean_absolute_error: 208.1046 - val_loss: 44866.2188 - val_mean_absolute_error: 211.6911
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 38730.7344 - mean_absolute_error: 194.0695 - val_loss: 38106.8750 - val_mean_absolute_error: 195.0741
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 32627.1758 - mean_absolute_error: 177.6106 - val_loss: 31738.7266 - val_mean_absolute_error: 178.0048
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 26605.9922 - mean_absolute_error: 159.8765 - val_loss: 25221.3945 - val_mean_absolute_error: 158.6449
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 20016.4941 - mean_absolute_error: 137.6814 - val_loss: 18798.6875 - val_mean_absolute_error: 136.9147
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 14367.4277 - mean_absolute_error: 115.8317 - val_loss: 13381.1279 - val_mean_absolute_error: 115.4454
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 10562.0225 - mean_absolute_error: 97.1496 - val_loss: 8577.1016 - val_mean_absolute_error: 92.3253
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6144.6079 - mean_absolute_error: 71.5578 - val_loss: 5341.8691 - val_mean_absolute_error: 72.7249
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4092.4082 - mean_absolute_error: 55.3221 - val_loss: 3104.2502 - val_mean_absolute_error: 55.2382
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2087.5540 - mean_absolute_error: 36.0536 - val_loss: 1619.4282 - val_mean_absolute_error: 39.5744
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1555.0018 - mean_absolute_error: 32.6906 - val_loss: 718.0665 - val_mean_absolute_error: 25.7896
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1010.6412 - mean_absolute_error: 26.9231 - val_loss: 351.1884 - val_mean_absolute_error: 17.2691
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1075.5712 - mean_absolute_error: 27.9358 - val_loss: 215.1792 - val_mean_absolute_error: 12.9752
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1013.8146 - mean_absolute_error: 26.6729 - val_loss: 174.2541 - val_mean_absolute_error: 11.3898
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1038.6656 - mean_absolute_error: 27.1811 - val_loss: 178.8278 - val_mean_absolute_error: 11.5791
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1075.1783 - mean_absolute_error: 28.1563 - val_loss: 196.1758 - val_mean_absolute_error: 12.2675
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 988.2015 - mean_absolute_error: 26.3673 - val_loss: 232.5284 - val_mean_absolute_error: 13.5859
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 971.5769 - mean_absolute_error: 26.2942 - val_loss: 256.3243 - val_mean_absolute_error: 14.3774
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 972.5985 - mean_absolute_error: 26.1663 - val_loss: 266.8701 - val_mean_absolute_error: 14.7132
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1036.1675 - mean_absolute_error: 27.0964 - val_loss: 273.9121 - val_mean_absolute_error: 14.9329
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1010.4343 - mean_absolute_error: 26.6900 - val_loss: 278.5301 - val_mean_absolute_error: 15.0751
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1025.8258 - mean_absolute_error: 26.9975 - val_loss: 284.2000 - val_mean_absolute_error: 15.2477
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1070.4069 - mean_absolute_error: 28.0589 - val_loss: 284.5078 - val_mean_absolute_error: 15.2570
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 997.9226 - mean_absolute_error: 26.7577 - val_loss: 310.1355 - val_mean_absolute_error: 16.0425
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 986.4852 - mean_absolute_error: 26.2923 - val_loss: 291.7553 - val_mean_absolute_error: 15.4769
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1094.6216 - mean_absolute_error: 28.3704 - val_loss: 286.5866 - val_mean_absolute_error: 15.3245
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1055.2279 - mean_absolute_error: 27.9145 - val_loss: 292.7194 - val_mean_absolute_error: 15.5078
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 975.5747 - mean_absolute_error: 26.3925 - val_loss: 290.8685 - val_mean_absolute_error: 15.4533
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 955.6099 - mean_absolute_error: 26.2230 - val_loss: 467.1073 - val_mean_absolute_error: 20.5056
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 899.5426 - mean_absolute_error: 25.6036 - val_loss: 285.0434 - val_mean_absolute_error: 15.3692
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 872.0161 - mean_absolute_error: 25.0067 - val_loss: 275.6774 - val_mean_absolute_error: 15.1280
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 724.1779 - mean_absolute_error: 22.2155 - val_loss: 296.8736 - val_mean_absolute_error: 15.8707
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 749.8442 - mean_absolute_error: 23.2369 - val_loss: 292.2731 - val_mean_absolute_error: 15.7533
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 773.4304 - mean_absolute_error: 23.3176 - val_loss: 482.2112 - val_mean_absolute_error: 20.9852
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 737.6774 - mean_absolute_error: 23.1404 - val_loss: 165.0417 - val_mean_absolute_error: 11.2801
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 682.8260 - mean_absolute_error: 22.1195 - val_loss: 115.3624 - val_mean_absolute_error: 8.9454
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 668.8289 - mean_absolute_error: 21.9674 - val_loss: 309.3091 - val_mean_absolute_error: 16.4493
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 558.0434 - mean_absolute_error: 19.7022 - val_loss: 230.9783 - val_mean_absolute_error: 13.8898
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 547.4592 - mean_absolute_error: 19.5323 - val_loss: 235.6643 - val_mean_absolute_error: 14.0826
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 583.4578 - mean_absolute_error: 19.9218 - val_loss: 83.4633 - val_mean_absolute_error: 7.4892
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 472.4043 - mean_absolute_error: 18.0081 - val_loss: 84.3216 - val_mean_absolute_error: 7.5168
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 452.9420 - mean_absolute_error: 17.5319 - val_loss: 279.1251 - val_mean_absolute_error: 15.6598
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 408.2045 - mean_absolute_error: 16.9908 - val_loss: 85.4406 - val_mean_absolute_error: 7.6594
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 347.3881 - mean_absolute_error: 15.1935 - val_loss: 109.8686 - val_mean_absolute_error: 9.0073
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 319.5901 - mean_absolute_error: 14.4936 - val_loss: 74.2090 - val_mean_absolute_error: 7.0774
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 267.5551 - mean_absolute_error: 13.3975 - val_loss: 48.1536 - val_mean_absolute_error: 5.5776
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 227.6177 - mean_absolute_error: 12.1580 - val_loss: 77.7058 - val_mean_absolute_error: 7.3075
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 210.3237 - mean_absolute_error: 11.6484 - val_loss: 61.1721 - val_mean_absolute_error: 6.4275
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 160.8933 - mean_absolute_error: 9.7275 - val_loss: 34.8447 - val_mean_absolute_error: 5.0977
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 132.9383 - mean_absolute_error: 8.9487 - val_loss: 38.7138 - val_mean_absolute_error: 5.2693
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 116.7291 - mean_absolute_error: 8.3837 - val_loss: 54.2186 - val_mean_absolute_error: 6.1411
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 100.0458 - mean_absolute_error: 7.7238 - val_loss: 40.6196 - val_mean_absolute_error: 5.1732
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 104.6493 - mean_absolute_error: 8.5365 - val_loss: 46.1339 - val_mean_absolute_error: 5.3938
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 82.0379 - mean_absolute_error: 7.1792 - val_loss: 33.3217 - val_mean_absolute_error: 4.8614
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 61.8344 - mean_absolute_error: 6.0654 - val_loss: 34.5537 - val_mean_absolute_error: 4.8813
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 48.1096 - mean_absolute_error: 5.1627 - val_loss: 31.1417 - val_mean_absolute_error: 4.8198
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 49.1892 - mean_absolute_error: 5.2574 - val_loss: 38.7766 - val_mean_absolute_error: 5.3094
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 50.6074 - mean_absolute_error: 5.5331 - val_loss: 32.9174 - val_mean_absolute_error: 4.8924
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 47.1862 - mean_absolute_error: 5.4948 - val_loss: 43.3373 - val_mean_absolute_error: 5.2495
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 42.1236 - mean_absolute_error: 5.2604 - val_loss: 69.4571 - val_mean_absolute_error: 6.6374
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 34.5985 - mean_absolute_error: 4.7744 - val_loss: 68.8927 - val_mean_absolute_error: 6.5947
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 32.1759 - mean_absolute_error: 4.6297 - val_loss: 39.5934 - val_mean_absolute_error: 5.0498
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 29.3254 - mean_absolute_error: 4.2077 - val_loss: 36.6836 - val_mean_absolute_error: 4.8998
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 27.1735 - mean_absolute_error: 3.9562 - val_loss: 39.1105 - val_mean_absolute_error: 5.0072
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 27.1778 - mean_absolute_error: 4.0365 - val_loss: 48.4015 - val_mean_absolute_error: 5.6175
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 23.3687 - mean_absolute_error: 3.8501 - val_loss: 47.8674 - val_mean_absolute_error: 5.5971
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 27.5870 - mean_absolute_error: 4.1772 - val_loss: 60.0692 - val_mean_absolute_error: 6.1645
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 26.1541 - mean_absolute_error: 4.2270 - val_loss: 39.4065 - val_mean_absolute_error: 5.0414
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 21.2382 - mean_absolute_error: 3.6738 - val_loss: 49.1727 - val_mean_absolute_error: 5.6717
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 19.6065 - mean_absolute_error: 3.5267 - val_loss: 34.0299 - val_mean_absolute_error: 4.7959
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 21.3149 - mean_absolute_error: 3.6558 - val_loss: 42.3366 - val_mean_absolute_error: 5.2653
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 19.7291 - mean_absolute_error: 3.5983 - val_loss: 37.9333 - val_mean_absolute_error: 4.9426
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 18.5471 - mean_absolute_error: 3.4974 - val_loss: 34.8744 - val_mean_absolute_error: 4.8017
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 21.8491 - mean_absolute_error: 3.7208 - val_loss: 48.1471 - val_mean_absolute_error: 5.6284
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 20.2590 - mean_absolute_error: 3.4509 - val_loss: 42.5422 - val_mean_absolute_error: 5.2758
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18.3296 - mean_absolute_error: 3.4679 - val_loss: 41.3405 - val_mean_absolute_error: 5.1881
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 18.3499 - mean_absolute_error: 3.3619 - val_loss: 38.0728 - val_mean_absolute_error: 4.9491
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 17.5260 - mean_absolute_error: 3.2993 - val_loss: 36.1028 - val_mean_absolute_error: 4.8269
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 21.1644 - mean_absolute_error: 3.6589 - val_loss: 33.5064 - val_mean_absolute_error: 4.7528
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 17.4941 - mean_absolute_error: 3.2666 - val_loss: 53.0093 - val_mean_absolute_error: 5.8915
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 16.3438 - mean_absolute_error: 3.1702 - val_loss: 35.3297 - val_mean_absolute_error: 4.7990

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %%
test_predictions = model.predict(X_test)

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)

plt.legend(['Training Predictions', 'Training Observations', 'Validation Predictions', 'Validation Observations', 'Test Predictions', 'Test Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val,dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)

plt.legend(['Training Predictions', 'Training Observations', 'Validation Predictions', 'Validation Observations', 'Test Predictions', 'Test Observations', 'Recursive Predictiolns'])
